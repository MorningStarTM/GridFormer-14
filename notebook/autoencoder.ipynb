# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# 'e:\\github_clone\\GridFormer-14'

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from gridformer.Utils.dataset import load_observation, ObsDataset, DataLoader

# %%
class AutoEncoder(nn.Module):
    def __init__(self, config) -> None:
        super(AutoEncoder, self).__init__()
        self.config = config
        input_dim = self.config.input_dim
        latent_dim = self.config.latent_dim

        self.encoder = nn.Sequential(
                        nn.Linear(input_dim, input_dim//2),
                        nn.ReLU(),
                        nn.Linear(input_dim//2, input_dim//4),
                        nn.ReLU(),
                        nn.Linear(input_dim//4, input_dim//8),
                        nn.ReLU(),
                        nn.Linear(input_dim//8, self.config.latent_dim)
        )

        self.decoder = nn.Sequential(
                        nn.Linear(latent_dim, latent_dim*2),
                        nn.ReLU(),
                        nn.Linear(latent_dim*2, latent_dim*4),
                        nn.ReLU(),
                        nn.Linear(latent_dim*4, latent_dim*8),
                        nn.ReLU(),
                        nn.Linear(latent_dim*8, input_dim)
        )

        self.optimizer = optim.Adam(self.parameters(), lr=0.00004)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.to(device=self.device)


    def forward(self, x):
        z = self.encoder(x)
        pred_x = self.decoder(z)
        return z, pred_x
    

    def save_model(self):
        torch.save(self.state_dict(), os.path.join(self.config.path, "autoEncoder.pt"))
        print(f"model saved at {self.config.path}")

    def load_model(self):
        self.load_state_dict(torch.load(os.path.join(self.config.path, "autoEncoder.pt")))
        print(f"model loaded at {self.config.path}")

    def train_data(self, dataloader, data_variance, save_path=None):
        
        best_score = float('inf')
        num = 0
        for observation in dataloader:
            num += 1
            z, pred_x = self.forward(observation)
            loss = F.mse_loss(pred_x, observation) #/ data_variance

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
                


            print(
                f"Epoch {num} - "
                f"Reconstruction Loss: {loss:.4f}, "
            ) 

            if loss < best_score:
                self.save_model()
                best_score = loss

    
    def evaluate(self, dataloader, data_variance):
        self.eval()
        total_loss = 0
        num = 0
        with torch.no_grad():
            for observation in dataloader:
                num += 1
                z, pred_x = self.forward(observation)
                loss = F.mse_loss(pred_x, observation) #/ data_variance
                    
                total_loss += loss.item()

        print(
            f"Epoch {num} - "
            f"Reconstruction Loss: {(total_loss / num):.4f}, "
        )

# %%
class Config:
    input_dim = 467
    latent_dim = 64
    path = "gridformer\\models"

# %%
config = Config()
ae = AutoEncoder(config)

# %%
obs = load_observation("C:\\Users\\Ernest\\Downloads\\topo_data", start=0, end=5)
dataset = ObsDataset(obs, device=ae.device)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
data_variance = np.var(obs)

# %%
ae.train_data(dataloader=dataloader, data_variance=data_variance)
# Out:
# Epoch 1 - Reconstruction Loss: 1090.2736,
# model saved at gridformer\models
# Epoch 2 - Reconstruction Loss: 1154.6630,
# Epoch 3 - Reconstruction Loss: 1841.3090,
# Epoch 4 - Reconstruction Loss: 1380.3938,
# Epoch 5 - Reconstruction Loss: 1538.9746,
# Epoch 6 - Reconstruction Loss: 1750.6334,
# Epoch 7 - Reconstruction Loss: 1174.0406,
# Epoch 8 - Reconstruction Loss: 943.7601,
# model saved at gridformer\models
# Epoch 9 - Reconstruction Loss: 1757.3833,
# Epoch 10 - Reconstruction Loss: 1701.3608,
# Epoch 11 - Reconstruction Loss: 1241.8396,
# Epoch 12 - Reconstruction Loss: 1592.6758,
# Epoch 13 - Reconstruction Loss: 1390.4172,
# Epoch 14 - Reconstruction Loss: 1142.2469,
# Epoch 15 - Reconstruction Loss: 920.0459,
# model saved at gridformer\models
# Epoch 16 - Reconstruction Loss: 1679.9768,
# Epoch 17 - Reconstruction Loss: 1286.1874,
# Epoch 18 - Reconstruction Loss: 1357.3896,
# Epoch 19 - Reconstruction Loss: 2058.0747,
# Epoch 20 - Reconstruction Loss: 2316.5647,
# Epoch 21 - Reconstruction Loss: 1331.8986,
# Epoch 22 - Reconstruction Loss: 1306.9015,
# Epoch 23 - Reconstruction Loss: 1539.4421,
# Epoch 24 - Reconstruction Loss: 1556.5516,
# Epoch 25 - Reconstruction Loss: 1124.1368,
# Epoch 26 - Reconstruction Loss: 1393.8903,
# Epoch 27 - Reconstruction Loss: 1240.2477,
# Epoch 28 - Reconstruction Loss: 1133.9103,
# Epoch 29 - Reconstruction Loss: 1118.0673,
# Epoch 30 - Reconstruction Loss: 976.8423,
# Epoch 31 - Reconstruction Loss: 1334.6490,
# Epoch 32 - Reconstruction Loss: 906.5355,
# model saved at gridformer\models
# Epoch 33 - Reconstruction Loss: 1716.6802,
# Epoch 34 - Reconstruction Loss: 1267.3594,
# Epoch 35 - Reconstruction Loss: 1572.4585,
# Epoch 36 - Reconstruction Loss: 1754.2581,
# Epoch 37 - Reconstruction Loss: 1930.3461,
# Epoch 38 - Reconstruction Loss: 1117.1351,
# Epoch 39 - Reconstruction Loss: 1592.4835,
# Epoch 40 - Reconstruction Loss: 1234.2170,
# Epoch 41 - Reconstruction Loss: 1132.1455,
# Epoch 42 - Reconstruction Loss: 1590.0988,
# Epoch 43 - Reconstruction Loss: 1316.1172,
# Epoch 44 - Reconstruction Loss: 1510.3822,
# Epoch 45 - Reconstruction Loss: 1276.7141,
# Epoch 46 - Reconstruction Loss: 1643.4722,
# Epoch 47 - Reconstruction Loss: 990.5083,
# Epoch 48 - Reconstruction Loss: 1405.5913,
# Epoch 49 - Reconstruction Loss: 1644.7952,
# Epoch 50 - Reconstruction Loss: 1543.3265,
# Epoch 51 - Reconstruction Loss: 1146.7874,
# Epoch 52 - Reconstruction Loss: 1211.1582,
# Epoch 53 - Reconstruction Loss: 1434.6594,
# Epoch 54 - Reconstruction Loss: 2188.8235,
# Epoch 55 - Reconstruction Loss: 1450.4124,
# Epoch 56 - Reconstruction Loss: 1780.6008,
# Epoch 57 - Reconstruction Loss: 1184.6295,
# Epoch 58 - Reconstruction Loss: 1886.7240,
# Epoch 59 - Reconstruction Loss: 1342.0188,
# Epoch 60 - Reconstruction Loss: 859.4431,
# model saved at gridformer\models
# Epoch 61 - Reconstruction Loss: 1583.5840,
# Epoch 62 - Reconstruction Loss: 1420.5996,
# Epoch 63 - Reconstruction Loss: 1096.0833,
# Epoch 64 - Reconstruction Loss: 1280.6332,
# Epoch 65 - Reconstruction Loss: 1062.3309,
# Epoch 66 - Reconstruction Loss: 1370.4344,
# Epoch 67 - Reconstruction Loss: 1372.8284,
# Epoch 68 - Reconstruction Loss: 1210.5402,
# Epoch 69 - Reconstruction Loss: 941.2656,
# Epoch 70 - Reconstruction Loss: 1815.4127,
# Epoch 71 - Reconstruction Loss: 1476.9407,
# Epoch 72 - Reconstruction Loss: 1166.8887,
# Epoch 73 - Reconstruction Loss: 1215.1145,
# Epoch 74 - Reconstruction Loss: 2019.4960,
# Epoch 75 - Reconstruction Loss: 1574.5730,
# Epoch 76 - Reconstruction Loss: 726.8922,
# model saved at gridformer\models
# Epoch 77 - Reconstruction Loss: 1563.2347,
# Epoch 78 - Reconstruction Loss: 1476.8295,
# Epoch 79 - Reconstruction Loss: 1087.0985,
# Epoch 80 - Reconstruction Loss: 2100.2085,
# Epoch 81 - Reconstruction Loss: 1136.6366,
# Epoch 82 - Reconstruction Loss: 1346.7190,
# Epoch 83 - Reconstruction Loss: 1263.3534,
# Epoch 84 - Reconstruction Loss: 981.7958,
# Epoch 85 - Reconstruction Loss: 1087.5997,
# Epoch 86 - Reconstruction Loss: 647.7583,
# model saved at gridformer\models
# Epoch 87 - Reconstruction Loss: 1552.6630,
# Epoch 88 - Reconstruction Loss: 807.5540,
# Epoch 89 - Reconstruction Loss: 789.5149,
# Epoch 90 - Reconstruction Loss: 1705.6057,
# Epoch 91 - Reconstruction Loss: 2040.0411,
# Epoch 92 - Reconstruction Loss: 1800.3403,
# Epoch 93 - Reconstruction Loss: 1413.7628,
# Epoch 94 - Reconstruction Loss: 1109.6522,
# Epoch 95 - Reconstruction Loss: 1291.4550,
# Epoch 96 - Reconstruction Loss: 937.0604,
# Epoch 97 - Reconstruction Loss: 1290.0537,
# Epoch 98 - Reconstruction Loss: 1743.4277,
# Epoch 99 - Reconstruction Loss: 1575.0123,
# Epoch 100 - Reconstruction Loss: 1440.4196,
# Epoch 101 - Reconstruction Loss: 1223.9545,
# Epoch 102 - Reconstruction Loss: 1838.6248,
# Epoch 103 - Reconstruction Loss: 1199.6215,
# Epoch 104 - Reconstruction Loss: 1027.1151,
# Epoch 105 - Reconstruction Loss: 1057.2701,
# Epoch 106 - Reconstruction Loss: 1797.0270,
# Epoch 107 - Reconstruction Loss: 1364.9567,
# Epoch 108 - Reconstruction Loss: 1684.8472,
# Epoch 109 - Reconstruction Loss: 2358.1082,
# Epoch 110 - Reconstruction Loss: 1293.3026,
# Epoch 111 - Reconstruction Loss: 1605.7601,
# Epoch 112 - Reconstruction Loss: 861.5460,
# Epoch 113 - Reconstruction Loss: 899.9532,
# Epoch 114 - Reconstruction Loss: 1377.1167,
# Epoch 115 - Reconstruction Loss: 1580.9202,
# Epoch 116 - Reconstruction Loss: 921.2583,
# Epoch 117 - Reconstruction Loss: 1832.2208,
# Epoch 118 - Reconstruction Loss: 1579.0038,
# Epoch 119 - Reconstruction Loss: 1875.1925,
# Epoch 120 - Reconstruction Loss: 1773.7192,
# Epoch 121 - Reconstruction Loss: 1462.1268,
# Epoch 122 - Reconstruction Loss: 1542.2329,
# Epoch 123 - Reconstruction Loss: 1325.0039,
# Epoch 124 - Reconstruction Loss: 901.9094,
# Epoch 125 - Reconstruction Loss: 1402.9785,
# Epoch 126 - Reconstruction Loss: 1683.9294,
# Epoch 127 - Reconstruction Loss: 1847.6991,
# Epoch 128 - Reconstruction Loss: 2393.1387,
# Epoch 129 - Reconstruction Loss: 2145.7903,
# Epoch 130 - Reconstruction Loss: 1389.0599,
# Epoch 131 - Reconstruction Loss: 1586.1959,
# Epoch 132 - Reconstruction Loss: 1406.1569,
# Epoch 133 - Reconstruction Loss: 1220.2422,
# Epoch 134 - Reconstruction Loss: 1113.8737,
# Epoch 135 - Reconstruction Loss: 1166.3685,
# Epoch 136 - Reconstruction Loss: 1608.7881,
# Epoch 137 - Reconstruction Loss: 1476.8894,
# Epoch 138 - Reconstruction Loss: 1423.1694,
# Epoch 139 - Reconstruction Loss: 1720.2327,
# Epoch 140 - Reconstruction Loss: 1784.4156,
# Epoch 141 - Reconstruction Loss: 1487.5823,
# Epoch 142 - Reconstruction Loss: 1164.1362,
# Epoch 143 - Reconstruction Loss: 747.8366,
# Epoch 144 - Reconstruction Loss: 1149.0942,
# Epoch 145 - Reconstruction Loss: 1463.6962,
# Epoch 146 - Reconstruction Loss: 1061.4633,
# Epoch 147 - Reconstruction Loss: 1482.2097,
# Epoch 148 - Reconstruction Loss: 1372.8419,
# Epoch 149 - Reconstruction Loss: 1517.2797,
# Epoch 150 - Reconstruction Loss: 957.2892,
# Epoch 151 - Reconstruction Loss: 1524.6580,
# Epoch 152 - Reconstruction Loss: 1456.5835,
# Epoch 153 - Reconstruction Loss: 812.1199,
# Epoch 154 - Reconstruction Loss: 1098.1132,
# Epoch 155 - Reconstruction Loss: 1387.1157,
# Epoch 156 - Reconstruction Loss: 1350.6483,
# Epoch 157 - Reconstruction Loss: 649.0228,
# Epoch 158 - Reconstruction Loss: 1673.8140,
# Epoch 159 - Reconstruction Loss: 1367.5736,
# Epoch 160 - Reconstruction Loss: 870.1835,
# Epoch 161 - Reconstruction Loss: 1479.1293,
# Epoch 162 - Reconstruction Loss: 1740.9175,
# Epoch 163 - Reconstruction Loss: 1066.1384,
# Epoch 164 - Reconstruction Loss: 1361.6313,
# Epoch 165 - Reconstruction Loss: 1887.5669,
# Epoch 166 - Reconstruction Loss: 1815.0305,
# Epoch 167 - Reconstruction Loss: 1012.9999,
# Epoch 168 - Reconstruction Loss: 1646.9193,
# Epoch 169 - Reconstruction Loss: 1177.7529,
# Epoch 170 - Reconstruction Loss: 1249.0265,
# Epoch 171 - Reconstruction Loss: 1313.0649,
# Epoch 172 - Reconstruction Loss: 1366.9965,
# Epoch 173 - Reconstruction Loss: 1855.6003,
# Epoch 174 - Reconstruction Loss: 1092.8964,
# Epoch 175 - Reconstruction Loss: 1496.9119,
# Epoch 176 - Reconstruction Loss: 1125.6823,
# Epoch 177 - Reconstruction Loss: 1843.5308,
# Epoch 178 - Reconstruction Loss: 1217.0902,
# Epoch 179 - Reconstruction Loss: 1919.1479,
# Epoch 180 - Reconstruction Loss: 1236.3088,
# Epoch 181 - Reconstruction Loss: 1612.3734,
# Epoch 182 - Reconstruction Loss: 1901.6432,
# Epoch 183 - Reconstruction Loss: 1483.9515,
# Epoch 184 - Reconstruction Loss: 909.9941,
# Epoch 185 - Reconstruction Loss: 2112.8083,
# Epoch 186 - Reconstruction Loss: 843.8686,
# Epoch 187 - Reconstruction Loss: 1159.4941,
# Epoch 188 - Reconstruction Loss: 1768.1394,
# Epoch 189 - Reconstruction Loss: 1208.4731,
# Epoch 190 - Reconstruction Loss: 1156.4973,
# Epoch 191 - Reconstruction Loss: 1392.1310,
# Epoch 192 - Reconstruction Loss: 1441.9585,
# Epoch 193 - Reconstruction Loss: 948.8778,
# Epoch 194 - Reconstruction Loss: 1767.1534,
# Epoch 195 - Reconstruction Loss: 1123.4963,
# Epoch 196 - Reconstruction Loss: 1077.2328,
# Epoch 197 - Reconstruction Loss: 1474.7849,
# Epoch 198 - Reconstruction Loss: 1561.9213,
# Epoch 199 - Reconstruction Loss: 675.2526,
# Epoch 200 - Reconstruction Loss: 1711.8561,
# Epoch 201 - Reconstruction Loss: 1239.0475,
# Epoch 202 - Reconstruction Loss: 2180.1033,
# Epoch 203 - Reconstruction Loss: 1467.6471,
# Epoch 204 - Reconstruction Loss: 1630.5872,
# Epoch 205 - Reconstruction Loss: 1438.9624,
# Epoch 206 - Reconstruction Loss: 1651.0750,
# Epoch 207 - Reconstruction Loss: 867.1839,
# Epoch 208 - Reconstruction Loss: 1348.4004,
# Epoch 209 - Reconstruction Loss: 1557.4344,
# Epoch 210 - Reconstruction Loss: 1449.1405,
# Epoch 211 - Reconstruction Loss: 817.8885,
# Epoch 212 - Reconstruction Loss: 1830.6028,
# Epoch 213 - Reconstruction Loss: 2086.2639,
# Epoch 214 - Reconstruction Loss: 1648.0125,
# Epoch 215 - Reconstruction Loss: 1583.2144,
# Epoch 216 - Reconstruction Loss: 1176.4213,
# Epoch 217 - Reconstruction Loss: 2123.7668,
# Epoch 218 - Reconstruction Loss: 1143.9353,
# Epoch 219 - Reconstruction Loss: 1504.0170,
# Epoch 220 - Reconstruction Loss: 1670.8076,
# Epoch 221 - Reconstruction Loss: 1796.9194,
# Epoch 222 - Reconstruction Loss: 1330.3502,
# Epoch 223 - Reconstruction Loss: 1287.3618,
# Epoch 224 - Reconstruction Loss: 1124.8295,
# Epoch 225 - Reconstruction Loss: 1237.1890,
# Epoch 226 - Reconstruction Loss: 883.2634,
# Epoch 227 - Reconstruction Loss: 1270.8212,
# Epoch 228 - Reconstruction Loss: 931.2537,
# Epoch 229 - Reconstruction Loss: 1487.7186,
# Epoch 230 - Reconstruction Loss: 768.2687,
# Epoch 231 - Reconstruction Loss: 1261.3846,
# Epoch 232 - Reconstruction Loss: 1949.0651,
# Epoch 233 - Reconstruction Loss: 1065.4106,
# Epoch 234 - Reconstruction Loss: 1029.6394,
# Epoch 235 - Reconstruction Loss: 1467.2090,
# Epoch 236 - Reconstruction Loss: 1640.8544,
# Epoch 237 - Reconstruction Loss: 1540.3181,
# Epoch 238 - Reconstruction Loss: 2021.1074,
# Epoch 239 - Reconstruction Loss: 1529.4540,
# Epoch 240 - Reconstruction Loss: 1604.4224,
# Epoch 241 - Reconstruction Loss: 1369.2769,
# Epoch 242 - Reconstruction Loss: 1516.7057,
# Epoch 243 - Reconstruction Loss: 1590.2224,
# Epoch 244 - Reconstruction Loss: 1854.5303,
# Epoch 245 - Reconstruction Loss: 1243.0632,
# Epoch 246 - Reconstruction Loss: 1766.4373,
# Epoch 247 - Reconstruction Loss: 1608.9851,
# Epoch 248 - Reconstruction Loss: 1352.8765,
# Epoch 249 - Reconstruction Loss: 1556.8295,
# Epoch 250 - Reconstruction Loss: 1250.1207,
# Epoch 251 - Reconstruction Loss: 861.0358,
# Epoch 252 - Reconstruction Loss: 1697.0447,
# Epoch 253 - Reconstruction Loss: 986.3688,
# Epoch 254 - Reconstruction Loss: 1634.2655,
# Epoch 255 - Reconstruction Loss: 1230.2853,
# Epoch 256 - Reconstruction Loss: 1476.0541,
# Epoch 257 - Reconstruction Loss: 1540.7527,
# Epoch 258 - Reconstruction Loss: 1439.3738,
# Epoch 259 - Reconstruction Loss: 1388.2146,
# Epoch 260 - Reconstruction Loss: 931.4124,
# Epoch 261 - Reconstruction Loss: 807.2524,
# Epoch 262 - Reconstruction Loss: 1386.2224,
# Epoch 263 - Reconstruction Loss: 1794.1084,
# Epoch 264 - Reconstruction Loss: 1064.9915,
# Epoch 265 - Reconstruction Loss: 1657.6571,
# Epoch 266 - Reconstruction Loss: 1797.5559,
# Epoch 267 - Reconstruction Loss: 1299.4528,
# Epoch 268 - Reconstruction Loss: 1407.8275,
# Epoch 269 - Reconstruction Loss: 1404.6367,
# Epoch 270 - Reconstruction Loss: 1800.1924,
# Epoch 271 - Reconstruction Loss: 1100.0770,
# Epoch 272 - Reconstruction Loss: 1190.0994,
# Epoch 273 - Reconstruction Loss: 1420.9459,
# Epoch 274 - Reconstruction Loss: 1344.8094,
# Epoch 275 - Reconstruction Loss: 1302.3734,
# Epoch 276 - Reconstruction Loss: 1684.0669,
# Epoch 277 - Reconstruction Loss: 1621.3779,
# Epoch 278 - Reconstruction Loss: 1932.7797,
# Epoch 279 - Reconstruction Loss: 1664.8303,
# Epoch 280 - Reconstruction Loss: 1298.3229,
# Epoch 281 - Reconstruction Loss: 1309.6002,
# Epoch 282 - Reconstruction Loss: 1888.8097,
# Epoch 283 - Reconstruction Loss: 1696.4183,
# Epoch 284 - Reconstruction Loss: 941.1325,
# Epoch 285 - Reconstruction Loss: 1946.6248,
# Epoch 286 - Reconstruction Loss: 1299.1447,
# Epoch 287 - Reconstruction Loss: 1182.7224,
# Epoch 288 - Reconstruction Loss: 1101.0520,
# Epoch 289 - Reconstruction Loss: 2025.0992,
# Epoch 290 - Reconstruction Loss: 1167.7827,
# Epoch 291 - Reconstruction Loss: 1567.0177,
# Epoch 292 - Reconstruction Loss: 1144.7622,
# Epoch 293 - Reconstruction Loss: 1311.2944,
# Epoch 294 - Reconstruction Loss: 1082.6931,
# Epoch 295 - Reconstruction Loss: 1159.0909,
# Epoch 296 - Reconstruction Loss: 1273.2173,
# Epoch 297 - Reconstruction Loss: 1468.7778,
# Epoch 298 - Reconstruction Loss: 1326.2938,
# Epoch 299 - Reconstruction Loss: 1456.9136,
# Epoch 300 - Reconstruction Loss: 857.8233,
# Epoch 301 - Reconstruction Loss: 1324.1636,
# Epoch 302 - Reconstruction Loss: 905.3451,
# Epoch 303 - Reconstruction Loss: 1415.0123,
# Epoch 304 - Reconstruction Loss: 1606.0936,
# Epoch 305 - Reconstruction Loss: 1353.2822,
# Epoch 306 - Reconstruction Loss: 1160.1541,
# Epoch 307 - Reconstruction Loss: 1698.8379,
# Epoch 308 - Reconstruction Loss: 1096.4106,
# Epoch 309 - Reconstruction Loss: 790.1990,
# Epoch 310 - Reconstruction Loss: 1794.5358,
# Epoch 311 - Reconstruction Loss: 1481.9736,
# Epoch 312 - Reconstruction Loss: 1507.3696,
# Epoch 313 - Reconstruction Loss: 906.5762,
# Epoch 314 - Reconstruction Loss: 1633.3943,
# Epoch 315 - Reconstruction Loss: 1578.7350,
# Epoch 316 - Reconstruction Loss: 1213.4283,
# Epoch 317 - Reconstruction Loss: 1607.1423,
# Epoch 318 - Reconstruction Loss: 1101.4131,
# Epoch 319 - Reconstruction Loss: 1314.0668,
# Epoch 320 - Reconstruction Loss: 1071.6663,
# Epoch 321 - Reconstruction Loss: 1956.3771,
# Epoch 322 - Reconstruction Loss: 1219.8660,
# Epoch 323 - Reconstruction Loss: 1141.9445,
# Epoch 324 - Reconstruction Loss: 2093.9443,
# Epoch 325 - Reconstruction Loss: 1556.7428,
# Epoch 326 - Reconstruction Loss: 1489.6802,
# Epoch 327 - Reconstruction Loss: 1868.2211,
# Epoch 328 - Reconstruction Loss: 1390.3820,
# Epoch 329 - Reconstruction Loss: 1153.8220,
# Epoch 330 - Reconstruction Loss: 1077.6376,
# Epoch 331 - Reconstruction Loss: 1660.3855,
# Epoch 332 - Reconstruction Loss: 1212.9414,
# Epoch 333 - Reconstruction Loss: 1949.3030,
# Epoch 334 - Reconstruction Loss: 966.2307,
# Epoch 335 - Reconstruction Loss: 1176.2888,
# Epoch 336 - Reconstruction Loss: 2007.4852,
# Epoch 337 - Reconstruction Loss: 930.3036,
# Epoch 338 - Reconstruction Loss: 1169.8063,
# Epoch 339 - Reconstruction Loss: 1104.5214,
# Epoch 340 - Reconstruction Loss: 1983.6708,
# Epoch 341 - Reconstruction Loss: 1725.8649,
# Epoch 342 - Reconstruction Loss: 1629.6599,
# Epoch 343 - Reconstruction Loss: 1739.5614,
# Epoch 344 - Reconstruction Loss: 1437.7866,
# Epoch 345 - Reconstruction Loss: 1813.0400,
# Epoch 346 - Reconstruction Loss: 2110.4006,
# Epoch 347 - Reconstruction Loss: 1664.6836,
# Epoch 348 - Reconstruction Loss: 1630.5166,
# Epoch 349 - Reconstruction Loss: 1686.9098,
# Epoch 350 - Reconstruction Loss: 1511.7428,
# Epoch 351 - Reconstruction Loss: 1491.5974,
# Epoch 352 - Reconstruction Loss: 1069.6682,
# Epoch 353 - Reconstruction Loss: 1014.6334,
# Epoch 354 - Reconstruction Loss: 1357.9296,
# Epoch 355 - Reconstruction Loss: 1293.1445,
# Epoch 356 - Reconstruction Loss: 1859.0728,
# Epoch 357 - Reconstruction Loss: 744.5646,
# Epoch 358 - Reconstruction Loss: 1931.5575,
# Epoch 359 - Reconstruction Loss: 1301.8723,
# Epoch 360 - Reconstruction Loss: 1966.6132,
# Epoch 361 - Reconstruction Loss: 732.2131,
# Epoch 362 - Reconstruction Loss: 1837.5640,
# Epoch 363 - Reconstruction Loss: 1346.4229,
# Epoch 364 - Reconstruction Loss: 1828.0465,
# Epoch 365 - Reconstruction Loss: 823.0757,
# Epoch 366 - Reconstruction Loss: 2008.0892,
# Epoch 367 - Reconstruction Loss: 887.0317,
# Epoch 368 - Reconstruction Loss: 905.4489,
# Epoch 369 - Reconstruction Loss: 1773.7808,
# Epoch 370 - Reconstruction Loss: 1981.8550,
# Epoch 371 - Reconstruction Loss: 1414.1764,
# Epoch 372 - Reconstruction Loss: 1275.7417,
# Epoch 373 - Reconstruction Loss: 1333.0602,
# Epoch 374 - Reconstruction Loss: 1303.5513,
# Epoch 375 - Reconstruction Loss: 795.3057,
# Epoch 376 - Reconstruction Loss: 1150.2206,
# Epoch 377 - Reconstruction Loss: 1034.0242,
# Epoch 378 - Reconstruction Loss: 1622.7191,
# Epoch 379 - Reconstruction Loss: 2100.4941,
# Epoch 380 - Reconstruction Loss: 1475.2960,
# Epoch 381 - Reconstruction Loss: 1570.4807,
# Epoch 382 - Reconstruction Loss: 984.0934,
# Epoch 383 - Reconstruction Loss: 2050.3640,
# Epoch 384 - Reconstruction Loss: 1712.8135,
# Epoch 385 - Reconstruction Loss: 1322.3146,
# Epoch 386 - Reconstruction Loss: 1974.9493,
# Epoch 387 - Reconstruction Loss: 770.3291,
# Epoch 388 - Reconstruction Loss: 1967.7253,
# Epoch 389 - Reconstruction Loss: 1127.6852,
# Epoch 390 - Reconstruction Loss: 970.8528,
# Epoch 391 - Reconstruction Loss: 1925.8589,
# Epoch 392 - Reconstruction Loss: 1367.0934,
# Epoch 393 - Reconstruction Loss: 1388.1448,
# Epoch 394 - Reconstruction Loss: 1121.5253,
# Epoch 395 - Reconstruction Loss: 550.7834,
# model saved at gridformer\models
# Epoch 396 - Reconstruction Loss: 886.1365,
# Epoch 397 - Reconstruction Loss: 848.0450,
# Epoch 398 - Reconstruction Loss: 1401.2709,
# Epoch 399 - Reconstruction Loss: 1869.9547,
# Epoch 400 - Reconstruction Loss: 711.2410,
# Epoch 401 - Reconstruction Loss: 1575.2000,
# Epoch 402 - Reconstruction Loss: 1322.6991,
# Epoch 403 - Reconstruction Loss: 716.7050,
# Epoch 404 - Reconstruction Loss: 768.6227,
# Epoch 405 - Reconstruction Loss: 1367.6479,
# Epoch 406 - Reconstruction Loss: 889.8784,
# Epoch 407 - Reconstruction Loss: 1543.2709,
# Epoch 408 - Reconstruction Loss: 885.4832,
# Epoch 409 - Reconstruction Loss: 1798.9430,
# Epoch 410 - Reconstruction Loss: 1530.7150,
# Epoch 411 - Reconstruction Loss: 1258.0918,
# Epoch 412 - Reconstruction Loss: 1125.2013,
# Epoch 413 - Reconstruction Loss: 1134.8601,
# Epoch 414 - Reconstruction Loss: 1432.2781,
# Epoch 415 - Reconstruction Loss: 1433.9480,
# Epoch 416 - Reconstruction Loss: 750.3004,
# Epoch 417 - Reconstruction Loss: 1546.9026,
# Epoch 418 - Reconstruction Loss: 1398.7533,
# Epoch 419 - Reconstruction Loss: 1193.7775,
# Epoch 420 - Reconstruction Loss: 1331.7075,
# Epoch 421 - Reconstruction Loss: 1946.5063,
# Epoch 422 - Reconstruction Loss: 880.9396,
# Epoch 423 - Reconstruction Loss: 1297.9624,
# Epoch 424 - Reconstruction Loss: 1380.2056,
# Epoch 425 - Reconstruction Loss: 1381.6583,
# Epoch 426 - Reconstruction Loss: 2025.9639,
# Epoch 427 - Reconstruction Loss: 1526.7300,
# Epoch 428 - Reconstruction Loss: 779.5995,
# Epoch 429 - Reconstruction Loss: 1644.1296,
# Epoch 430 - Reconstruction Loss: 1048.2650,
# Epoch 431 - Reconstruction Loss: 1158.9575,
# Epoch 432 - Reconstruction Loss: 1857.9015,
# Epoch 433 - Reconstruction Loss: 1980.9519,
# Epoch 434 - Reconstruction Loss: 1700.2869,
# Epoch 435 - Reconstruction Loss: 1117.8309,
# Epoch 436 - Reconstruction Loss: 1546.9331,
# Epoch 437 - Reconstruction Loss: 1526.3922,
# Epoch 438 - Reconstruction Loss: 970.0236,
# Epoch 439 - Reconstruction Loss: 1758.7499,
# Epoch 440 - Reconstruction Loss: 1829.1549,
# Epoch 441 - Reconstruction Loss: 1345.7654,
# Epoch 442 - Reconstruction Loss: 1738.1282,
# Epoch 443 - Reconstruction Loss: 1148.2946,
# Epoch 444 - Reconstruction Loss: 1055.0226,
# Epoch 445 - Reconstruction Loss: 926.9999,
# Epoch 446 - Reconstruction Loss: 1326.6533,
# Epoch 447 - Reconstruction Loss: 1532.8052,
# Epoch 448 - Reconstruction Loss: 1067.7212,
# Epoch 449 - Reconstruction Loss: 1519.9780,
# Epoch 450 - Reconstruction Loss: 1817.8402,
# Epoch 451 - Reconstruction Loss: 1452.5355,
# Epoch 452 - Reconstruction Loss: 1885.2257,
# Epoch 453 - Reconstruction Loss: 1415.0530,
# Epoch 454 - Reconstruction Loss: 1688.2633,
# Epoch 455 - Reconstruction Loss: 1699.6392,
# Epoch 456 - Reconstruction Loss: 1450.4840,
# Epoch 457 - Reconstruction Loss: 1622.0616,
# Epoch 458 - Reconstruction Loss: 1371.0573,
# Epoch 459 - Reconstruction Loss: 1193.9946,
# Epoch 460 - Reconstruction Loss: 1330.2826,
# Epoch 461 - Reconstruction Loss: 1880.9972,
# Epoch 462 - Reconstruction Loss: 1705.3225,
# Epoch 463 - Reconstruction Loss: 1259.7560,
# Epoch 464 - Reconstruction Loss: 1458.3943,
# Epoch 465 - Reconstruction Loss: 1204.9626,
# Epoch 466 - Reconstruction Loss: 796.8641,
# Epoch 467 - Reconstruction Loss: 1365.0476,
# Epoch 468 - Reconstruction Loss: 1320.8126,
# Epoch 469 - Reconstruction Loss: 2143.3315,
# Epoch 470 - Reconstruction Loss: 759.3523,
# Epoch 471 - Reconstruction Loss: 1056.5220,
# Epoch 472 - Reconstruction Loss: 1159.6887,
# Epoch 473 - Reconstruction Loss: 1331.9946,
# Epoch 474 - Reconstruction Loss: 717.5478,
# Epoch 475 - Reconstruction Loss: 885.7576,
# Epoch 476 - Reconstruction Loss: 904.3243,
# Epoch 477 - Reconstruction Loss: 1429.0642,
# Epoch 478 - Reconstruction Loss: 888.8448,
# Epoch 479 - Reconstruction Loss: 2219.1667,
# Epoch 480 - Reconstruction Loss: 952.4393,
# Epoch 481 - Reconstruction Loss: 1562.0763,
# Epoch 482 - Reconstruction Loss: 869.8775,
# Epoch 483 - Reconstruction Loss: 1446.8784,
# Epoch 484 - Reconstruction Loss: 2298.2666,
# Epoch 485 - Reconstruction Loss: 1466.7738,
# Epoch 486 - Reconstruction Loss: 1227.5375,
# Epoch 487 - Reconstruction Loss: 1357.8860,
# Epoch 488 - Reconstruction Loss: 1573.4774,
# Epoch 489 - Reconstruction Loss: 1183.2781,
# Epoch 490 - Reconstruction Loss: 1410.9521,
# Epoch 491 - Reconstruction Loss: 896.9603,
# Epoch 492 - Reconstruction Loss: 1116.3413,
# Epoch 493 - Reconstruction Loss: 1374.4991,
# Epoch 494 - Reconstruction Loss: 1430.8965,
# Epoch 495 - Reconstruction Loss: 1353.8506,
# Epoch 496 - Reconstruction Loss: 1404.8287,
# Epoch 497 - Reconstruction Loss: 1866.2029,
# Epoch 498 - Reconstruction Loss: 1221.1210,
# Epoch 499 - Reconstruction Loss: 1563.5022,
# Epoch 500 - Reconstruction Loss: 846.4855,
# Epoch 501 - Reconstruction Loss: 1278.8601,
# Epoch 502 - Reconstruction Loss: 1772.6702,
# Epoch 503 - Reconstruction Loss: 1600.5187,
# Epoch 504 - Reconstruction Loss: 915.5320,
# Epoch 505 - Reconstruction Loss: 1335.6835,
# Epoch 506 - Reconstruction Loss: 1661.1281,
# Epoch 507 - Reconstruction Loss: 914.2117,
# Epoch 508 - Reconstruction Loss: 892.2524,
# Epoch 509 - Reconstruction Loss: 1067.9404,
# Epoch 510 - Reconstruction Loss: 1595.0413,
# Epoch 511 - Reconstruction Loss: 1286.8113,
# Epoch 512 - Reconstruction Loss: 1119.7046,
# Epoch 513 - Reconstruction Loss: 2049.5696,
# Epoch 514 - Reconstruction Loss: 1062.5642,
# Epoch 515 - Reconstruction Loss: 1552.5103,
# Epoch 516 - Reconstruction Loss: 1310.5040,
# Epoch 517 - Reconstruction Loss: 1451.8020,
# Epoch 518 - Reconstruction Loss: 1608.3145,
# Epoch 519 - Reconstruction Loss: 1337.1431,
# Epoch 520 - Reconstruction Loss: 1222.6102,
# Epoch 521 - Reconstruction Loss: 1456.6158,
# Epoch 522 - Reconstruction Loss: 1041.4921,
# Epoch 523 - Reconstruction Loss: 1877.5243,
# Epoch 524 - Reconstruction Loss: 1450.2555,
# Epoch 525 - Reconstruction Loss: 1173.6060,
# Epoch 526 - Reconstruction Loss: 664.9216,
# Epoch 527 - Reconstruction Loss: 916.4285,
# Epoch 528 - Reconstruction Loss: 1251.9392,
# Epoch 529 - Reconstruction Loss: 1869.8109,
# Epoch 530 - Reconstruction Loss: 1005.7883,
# Epoch 531 - Reconstruction Loss: 2211.9109,
# Epoch 532 - Reconstruction Loss: 1818.5256,
# Epoch 533 - Reconstruction Loss: 1400.7727,
# Epoch 534 - Reconstruction Loss: 2369.3892,
# Epoch 535 - Reconstruction Loss: 2065.3579,
# Epoch 536 - Reconstruction Loss: 1019.5302,
# Epoch 537 - Reconstruction Loss: 1212.3899,
# Epoch 538 - Reconstruction Loss: 1268.7195,
# Epoch 539 - Reconstruction Loss: 1381.3618,
# Epoch 540 - Reconstruction Loss: 1222.4591,
# Epoch 541 - Reconstruction Loss: 1273.7583,
# Epoch 542 - Reconstruction Loss: 608.1325,
# Epoch 543 - Reconstruction Loss: 1256.6986,
# Epoch 544 - Reconstruction Loss: 1794.0508,
# Epoch 545 - Reconstruction Loss: 1168.5479,
# Epoch 546 - Reconstruction Loss: 1494.4630,
# Epoch 547 - Reconstruction Loss: 893.9404,
# Epoch 548 - Reconstruction Loss: 1069.4558,
# Epoch 549 - Reconstruction Loss: 986.6240,
# Epoch 550 - Reconstruction Loss: 1132.3993,
# Epoch 551 - Reconstruction Loss: 1344.2277,
# Epoch 552 - Reconstruction Loss: 1388.6802,
# Epoch 553 - Reconstruction Loss: 1414.8470,
# Epoch 554 - Reconstruction Loss: 921.8082,
# Epoch 555 - Reconstruction Loss: 1496.7173,
# Epoch 556 - Reconstruction Loss: 1210.6921,
# Epoch 557 - Reconstruction Loss: 1043.9995,
# Epoch 558 - Reconstruction Loss: 2365.2078,
# Epoch 559 - Reconstruction Loss: 1121.1537,
# Epoch 560 - Reconstruction Loss: 1376.8728,
# Epoch 561 - Reconstruction Loss: 722.9925,
# Epoch 562 - Reconstruction Loss: 1540.3549,
# Epoch 563 - Reconstruction Loss: 1438.8102,
# Epoch 564 - Reconstruction Loss: 1256.5127,
# Epoch 565 - Reconstruction Loss: 1745.2168,
# Epoch 566 - Reconstruction Loss: 1874.4475,
# Epoch 567 - Reconstruction Loss: 1207.2864,
# Epoch 568 - Reconstruction Loss: 1552.8135,
# Epoch 569 - Reconstruction Loss: 1587.0732,
# Epoch 570 - Reconstruction Loss: 1617.8667,
# Epoch 571 - Reconstruction Loss: 1659.4553,
# Epoch 572 - Reconstruction Loss: 1705.4919,
# Epoch 573 - Reconstruction Loss: 1197.3643,
# Epoch 574 - Reconstruction Loss: 1111.9591,
# Epoch 575 - Reconstruction Loss: 2927.9670,
# Epoch 576 - Reconstruction Loss: 1649.6986,
# Epoch 577 - Reconstruction Loss: 1299.1433,
# Epoch 578 - Reconstruction Loss: 1203.6655,
# Epoch 579 - Reconstruction Loss: 1513.7015,
# Epoch 580 - Reconstruction Loss: 1297.2975,
# Epoch 581 - Reconstruction Loss: 1760.1571,
# Epoch 582 - Reconstruction Loss: 1582.0764,
# Epoch 583 - Reconstruction Loss: 1812.4291,
# Epoch 584 - Reconstruction Loss: 1758.4060,
# Epoch 585 - Reconstruction Loss: 1598.4480,
# Epoch 586 - Reconstruction Loss: 1733.8845,
# Epoch 587 - Reconstruction Loss: 1392.8230,
# Epoch 588 - Reconstruction Loss: 1336.5870,
# Epoch 589 - Reconstruction Loss: 1519.8774,
# Epoch 590 - Reconstruction Loss: 1461.3225,
# Epoch 591 - Reconstruction Loss: 1351.4105,
# Epoch 592 - Reconstruction Loss: 1198.9537,
# Epoch 593 - Reconstruction Loss: 1172.8218,
# Epoch 594 - Reconstruction Loss: 1864.3916,
# Epoch 595 - Reconstruction Loss: 1177.6111,
# Epoch 596 - Reconstruction Loss: 721.7661,
# Epoch 597 - Reconstruction Loss: 884.6791,
# Epoch 598 - Reconstruction Loss: 1102.0275,
# Epoch 599 - Reconstruction Loss: 1582.5824,
# Epoch 600 - Reconstruction Loss: 1227.0107,
# Epoch 601 - Reconstruction Loss: 1961.9307,
# Epoch 602 - Reconstruction Loss: 2388.8735,
# Epoch 603 - Reconstruction Loss: 1260.8639,
# Epoch 604 - Reconstruction Loss: 1257.1052,
# Epoch 605 - Reconstruction Loss: 1435.7485,
# Epoch 606 - Reconstruction Loss: 1509.2655,
# Epoch 607 - Reconstruction Loss: 1185.4265,
# Epoch 608 - Reconstruction Loss: 1719.8463,
# Epoch 609 - Reconstruction Loss: 895.2967,
# Epoch 610 - Reconstruction Loss: 1091.9340,
# Epoch 611 - Reconstruction Loss: 1561.4381,
# Epoch 612 - Reconstruction Loss: 962.6144,
# Epoch 613 - Reconstruction Loss: 1250.4119,
# Epoch 614 - Reconstruction Loss: 1923.3812,
# Epoch 615 - Reconstruction Loss: 1279.1676,
# Epoch 616 - Reconstruction Loss: 1611.9459,
# Epoch 617 - Reconstruction Loss: 1023.9958,
# Epoch 618 - Reconstruction Loss: 1520.1943,
# Epoch 619 - Reconstruction Loss: 2146.1970,
# Epoch 620 - Reconstruction Loss: 2430.3799,
# Epoch 621 - Reconstruction Loss: 2046.2191,
# Epoch 622 - Reconstruction Loss: 1301.9661,
# Epoch 623 - Reconstruction Loss: 1215.0879,
# Epoch 624 - Reconstruction Loss: 1292.0581,
# Epoch 625 - Reconstruction Loss: 915.9548,
# Epoch 626 - Reconstruction Loss: 1968.1793,
# Epoch 627 - Reconstruction Loss: 1503.2888,
# Epoch 628 - Reconstruction Loss: 1992.0422,
# Epoch 629 - Reconstruction Loss: 985.7564,
# Epoch 630 - Reconstruction Loss: 875.7966,
# Epoch 631 - Reconstruction Loss: 1113.4854,
# Epoch 632 - Reconstruction Loss: 1172.5625,
# Epoch 633 - Reconstruction Loss: 904.6387,
# Epoch 634 - Reconstruction Loss: 1896.1971,
# Epoch 635 - Reconstruction Loss: 1699.2568,
# Epoch 636 - Reconstruction Loss: 1286.6127,
# Epoch 637 - Reconstruction Loss: 809.8641,
# Epoch 638 - Reconstruction Loss: 810.9332,
# Epoch 639 - Reconstruction Loss: 1058.9420,
# Epoch 640 - Reconstruction Loss: 936.8873,
# Epoch 641 - Reconstruction Loss: 1866.5219,
# Epoch 642 - Reconstruction Loss: 1812.1814,
# Epoch 643 - Reconstruction Loss: 1413.3914,
# Epoch 644 - Reconstruction Loss: 928.8079,
# Epoch 645 - Reconstruction Loss: 1417.7588,
# Epoch 646 - Reconstruction Loss: 1495.3187,
# Epoch 647 - Reconstruction Loss: 1285.4238,
# Epoch 648 - Reconstruction Loss: 2291.4399,
# Epoch 649 - Reconstruction Loss: 1089.0103,
# Epoch 650 - Reconstruction Loss: 1410.7083,
# Epoch 651 - Reconstruction Loss: 1077.7361,
# Epoch 652 - Reconstruction Loss: 1674.3881,
# Epoch 653 - Reconstruction Loss: 1395.7123,
# Epoch 654 - Reconstruction Loss: 2097.1548,
# Epoch 655 - Reconstruction Loss: 1618.6976,
# Epoch 656 - Reconstruction Loss: 1176.9177,
# Epoch 657 - Reconstruction Loss: 1039.5997,
# Epoch 658 - Reconstruction Loss: 1123.5182,
# Epoch 659 - Reconstruction Loss: 1453.0594,
# Epoch 660 - Reconstruction Loss: 1154.4526,
# Epoch 661 - Reconstruction Loss: 819.0925,
# Epoch 662 - Reconstruction Loss: 1865.3928,
# Epoch 663 - Reconstruction Loss: 904.3877,
# Epoch 664 - Reconstruction Loss: 1769.1875,
# Epoch 665 - Reconstruction Loss: 923.6398,
# Epoch 666 - Reconstruction Loss: 682.3671,
# Epoch 667 - Reconstruction Loss: 2194.4529,
# Epoch 668 - Reconstruction Loss: 1798.6046,
# Epoch 669 - Reconstruction Loss: 1320.4106,
# Epoch 670 - Reconstruction Loss: 1474.6506,
# Epoch 671 - Reconstruction Loss: 1189.8910,
# Epoch 672 - Reconstruction Loss: 934.6489,
# Epoch 673 - Reconstruction Loss: 1164.2885,
# Epoch 674 - Reconstruction Loss: 977.2737,
# Epoch 675 - Reconstruction Loss: 1558.4984,
# Epoch 676 - Reconstruction Loss: 1120.8947,
# Epoch 677 - Reconstruction Loss: 667.1478,
# Epoch 678 - Reconstruction Loss: 1431.3110,
# Epoch 679 - Reconstruction Loss: 1166.3975,
# Epoch 680 - Reconstruction Loss: 1888.9275,
# Epoch 681 - Reconstruction Loss: 1946.1649,
# Epoch 682 - Reconstruction Loss: 1165.7740,
# Epoch 683 - Reconstruction Loss: 1166.7762,
# Epoch 684 - Reconstruction Loss: 1824.5225,
# Epoch 685 - Reconstruction Loss: 895.1195,
# Epoch 686 - Reconstruction Loss: 1244.4475,
# Epoch 687 - Reconstruction Loss: 1165.0621,
# Epoch 688 - Reconstruction Loss: 1650.6311,
# Epoch 689 - Reconstruction Loss: 1111.0403,
# Epoch 690 - Reconstruction Loss: 1141.1949,
# Epoch 691 - Reconstruction Loss: 1133.9232,
# Epoch 692 - Reconstruction Loss: 1150.5790,
# Epoch 693 - Reconstruction Loss: 770.1800,
# Epoch 694 - Reconstruction Loss: 731.3689,
# Epoch 695 - Reconstruction Loss: 1793.8052,
# Epoch 696 - Reconstruction Loss: 1058.6498,
# Epoch 697 - Reconstruction Loss: 1091.1208,
# Epoch 698 - Reconstruction Loss: 723.6494,
# Epoch 699 - Reconstruction Loss: 1035.5371,
# Epoch 700 - Reconstruction Loss: 1619.4625,
# Epoch 701 - Reconstruction Loss: 1476.0834,
# Epoch 702 - Reconstruction Loss: 2064.6870,
# Epoch 703 - Reconstruction Loss: 1239.5461,
# Epoch 704 - Reconstruction Loss: 1293.3500,
# Epoch 705 - Reconstruction Loss: 1444.1338,
# Epoch 706 - Reconstruction Loss: 1068.7795,
# Epoch 707 - Reconstruction Loss: 931.4476,
# Epoch 708 - Reconstruction Loss: 1747.8549,
# Epoch 709 - Reconstruction Loss: 1231.3671,
# Epoch 710 - Reconstruction Loss: 1460.4928,
# Epoch 711 - Reconstruction Loss: 1192.8765,
# Epoch 712 - Reconstruction Loss: 991.3441,
# Epoch 713 - Reconstruction Loss: 1645.3508,
# Epoch 714 - Reconstruction Loss: 1688.9414,
# Epoch 715 - Reconstruction Loss: 1699.7928,
# Epoch 716 - Reconstruction Loss: 871.4964,
# Epoch 717 - Reconstruction Loss: 1777.7219,
# Epoch 718 - Reconstruction Loss: 1711.3549,
# Epoch 719 - Reconstruction Loss: 983.1159,
# Epoch 720 - Reconstruction Loss: 794.3085,
# Epoch 721 - Reconstruction Loss: 1091.8225,
# Epoch 722 - Reconstruction Loss: 1258.2087,
# Epoch 723 - Reconstruction Loss: 1252.3684,
# Epoch 724 - Reconstruction Loss: 1346.2094,
# Epoch 725 - Reconstruction Loss: 1147.9017,
# Epoch 726 - Reconstruction Loss: 1409.7489,
# Epoch 727 - Reconstruction Loss: 1035.6013,
# Epoch 728 - Reconstruction Loss: 1461.0972,
# Epoch 729 - Reconstruction Loss: 523.7513,
# model saved at gridformer\models
# Epoch 730 - Reconstruction Loss: 1109.4769,
# Epoch 731 - Reconstruction Loss: 1061.1605,
# Epoch 732 - Reconstruction Loss: 1740.8169,
# Epoch 733 - Reconstruction Loss: 1756.0610,
# Epoch 734 - Reconstruction Loss: 1485.3817,
# Epoch 735 - Reconstruction Loss: 692.9080,
# Epoch 736 - Reconstruction Loss: 1279.1797,
# Epoch 737 - Reconstruction Loss: 911.7671,
# Epoch 738 - Reconstruction Loss: 985.8847,
# Epoch 739 - Reconstruction Loss: 1565.7802,
# Epoch 740 - Reconstruction Loss: 1404.4183,
# Epoch 741 - Reconstruction Loss: 1050.7957,
# Epoch 742 - Reconstruction Loss: 973.8411,
# Epoch 743 - Reconstruction Loss: 926.9103,
# Epoch 744 - Reconstruction Loss: 1033.5973,
# Epoch 745 - Reconstruction Loss: 1266.6183,
# Epoch 746 - Reconstruction Loss: 782.4536,
# Epoch 747 - Reconstruction Loss: 1703.2471,
# Epoch 748 - Reconstruction Loss: 1571.2855,
# Epoch 749 - Reconstruction Loss: 922.4550,
# Epoch 750 - Reconstruction Loss: 802.6184,
# Epoch 751 - Reconstruction Loss: 1704.1411,
# Epoch 752 - Reconstruction Loss: 1257.3846,
# Epoch 753 - Reconstruction Loss: 1843.2014,
# Epoch 754 - Reconstruction Loss: 1510.0708,
# Epoch 755 - Reconstruction Loss: 1738.5029,
# Epoch 756 - Reconstruction Loss: 1729.8344,
# Epoch 757 - Reconstruction Loss: 1484.5465,
# Epoch 758 - Reconstruction Loss: 1126.7382,
# Epoch 759 - Reconstruction Loss: 956.2737,
# Epoch 760 - Reconstruction Loss: 1424.2655,
# Epoch 761 - Reconstruction Loss: 1101.4843,
# Epoch 762 - Reconstruction Loss: 1484.8141,
# Epoch 763 - Reconstruction Loss: 1127.5269,
# Epoch 764 - Reconstruction Loss: 1172.7756,
# Epoch 765 - Reconstruction Loss: 1246.9280,
# Epoch 766 - Reconstruction Loss: 1064.7501,
# Epoch 767 - Reconstruction Loss: 1295.0698,
# Epoch 768 - Reconstruction Loss: 1232.7067,
# Epoch 769 - Reconstruction Loss: 1989.6400,
# Epoch 770 - Reconstruction Loss: 1217.1910,
# Epoch 771 - Reconstruction Loss: 1312.7323,
# Epoch 772 - Reconstruction Loss: 967.5577,
# Epoch 773 - Reconstruction Loss: 1116.6119,
# Epoch 774 - Reconstruction Loss: 955.9857,
# Epoch 775 - Reconstruction Loss: 1297.4347,
# Epoch 776 - Reconstruction Loss: 1630.2618,
# Epoch 777 - Reconstruction Loss: 1358.4059,
# Epoch 778 - Reconstruction Loss: 1331.7527,
# Epoch 779 - Reconstruction Loss: 2011.3790,
# Epoch 780 - Reconstruction Loss: 1101.3131,
# Epoch 781 - Reconstruction Loss: 732.6144,
# Epoch 782 - Reconstruction Loss: 1380.3414,
# Epoch 783 - Reconstruction Loss: 1274.3918,
# Epoch 784 - Reconstruction Loss: 1591.3806,
# Epoch 785 - Reconstruction Loss: 1227.7445,
# Epoch 786 - Reconstruction Loss: 1085.5614,
# Epoch 787 - Reconstruction Loss: 1719.4847,
# Epoch 788 - Reconstruction Loss: 1369.5005,
# Epoch 789 - Reconstruction Loss: 1287.9816,
# Epoch 790 - Reconstruction Loss: 1415.5964,
# Epoch 791 - Reconstruction Loss: 880.0876,
# Epoch 792 - Reconstruction Loss: 1544.7906,
# Epoch 793 - Reconstruction Loss: 988.3868,
# Epoch 794 - Reconstruction Loss: 1785.8339,
# Epoch 795 - Reconstruction Loss: 1550.3447,
# Epoch 796 - Reconstruction Loss: 1184.4795,
# Epoch 797 - Reconstruction Loss: 798.7293,
# Epoch 798 - Reconstruction Loss: 1001.9360,
# Epoch 799 - Reconstruction Loss: 924.0550,
# Epoch 800 - Reconstruction Loss: 1087.4353,
# Epoch 801 - Reconstruction Loss: 1353.5824,
# Epoch 802 - Reconstruction Loss: 924.2599,
# Epoch 803 - Reconstruction Loss: 1160.1852,
# Epoch 804 - Reconstruction Loss: 1448.2216,
# Epoch 805 - Reconstruction Loss: 1424.2238,
# Epoch 806 - Reconstruction Loss: 1196.7889,
# Epoch 807 - Reconstruction Loss: 1507.8943,
# Epoch 808 - Reconstruction Loss: 2040.7899,
# Epoch 809 - Reconstruction Loss: 1316.7430,
# Epoch 810 - Reconstruction Loss: 1459.1421,
# Epoch 811 - Reconstruction Loss: 1588.9836,
# Epoch 812 - Reconstruction Loss: 2052.2227,
# Epoch 813 - Reconstruction Loss: 1594.3236,
# Epoch 814 - Reconstruction Loss: 948.1413,
# Epoch 815 - Reconstruction Loss: 1527.6378,
# Epoch 816 - Reconstruction Loss: 1638.6515,
# Epoch 817 - Reconstruction Loss: 848.5215,
# Epoch 818 - Reconstruction Loss: 1408.5750,
# Epoch 819 - Reconstruction Loss: 1761.5254,
# Epoch 820 - Reconstruction Loss: 1169.1365,
# Epoch 821 - Reconstruction Loss: 1963.0256,
# Epoch 822 - Reconstruction Loss: 1215.6204,
# Epoch 823 - Reconstruction Loss: 1253.1780,
# Epoch 824 - Reconstruction Loss: 1627.6793,
# Epoch 825 - Reconstruction Loss: 1371.5570,
# Epoch 826 - Reconstruction Loss: 1345.4999,
# Epoch 827 - Reconstruction Loss: 470.5911,
# model saved at gridformer\models
# Epoch 828 - Reconstruction Loss: 1367.2594,
# Epoch 829 - Reconstruction Loss: 2425.5476,
# Epoch 830 - Reconstruction Loss: 1270.9906,
# Epoch 831 - Reconstruction Loss: 1061.8265,
# Epoch 832 - Reconstruction Loss: 1236.1888,
# Epoch 833 - Reconstruction Loss: 1144.1270,
# Epoch 834 - Reconstruction Loss: 1104.6761,
# Epoch 835 - Reconstruction Loss: 940.8877,
# Epoch 836 - Reconstruction Loss: 1443.5757,
# Epoch 837 - Reconstruction Loss: 1710.6003,
# Epoch 838 - Reconstruction Loss: 2051.6150,
# Epoch 839 - Reconstruction Loss: 1303.0027,
# Epoch 840 - Reconstruction Loss: 1411.8522,
# Epoch 841 - Reconstruction Loss: 1057.9027,
# Epoch 842 - Reconstruction Loss: 928.0198,
# Epoch 843 - Reconstruction Loss: 1064.1587,
# Epoch 844 - Reconstruction Loss: 1241.9061,
# Epoch 845 - Reconstruction Loss: 1889.0045,
# Epoch 846 - Reconstruction Loss: 1466.7682,
# Epoch 847 - Reconstruction Loss: 934.1342,
# Epoch 848 - Reconstruction Loss: 1734.2229,
# Epoch 849 - Reconstruction Loss: 1532.0824,
# Epoch 850 - Reconstruction Loss: 1345.9225,
# Epoch 851 - Reconstruction Loss: 825.7569,
# Epoch 852 - Reconstruction Loss: 1703.5752,
# Epoch 853 - Reconstruction Loss: 1667.2034,
# Epoch 854 - Reconstruction Loss: 986.3965,
# Epoch 855 - Reconstruction Loss: 1063.9762,
# Epoch 856 - Reconstruction Loss: 1542.5836,
# Epoch 857 - Reconstruction Loss: 994.0049,
# Epoch 858 - Reconstruction Loss: 1161.8202,
# Epoch 859 - Reconstruction Loss: 1674.8698,
# Epoch 860 - Reconstruction Loss: 1358.6251,
# Epoch 861 - Reconstruction Loss: 983.1089,
# Epoch 862 - Reconstruction Loss: 1349.4266,
# Epoch 863 - Reconstruction Loss: 900.6411,
# Epoch 864 - Reconstruction Loss: 1487.5167,
# Epoch 865 - Reconstruction Loss: 953.3799,
# Epoch 866 - Reconstruction Loss: 1660.0292,
# Epoch 867 - Reconstruction Loss: 724.2263,
# Epoch 868 - Reconstruction Loss: 2130.7490,
# Epoch 869 - Reconstruction Loss: 1627.4506,
# Epoch 870 - Reconstruction Loss: 1254.4955,
# Epoch 871 - Reconstruction Loss: 1459.7820,
# Epoch 872 - Reconstruction Loss: 1144.9121,
# Epoch 873 - Reconstruction Loss: 969.0757,
# Epoch 874 - Reconstruction Loss: 1323.5565,
# Epoch 875 - Reconstruction Loss: 1398.9493,
# Epoch 876 - Reconstruction Loss: 1912.4194,
# Epoch 877 - Reconstruction Loss: 1047.7354,
# Epoch 878 - Reconstruction Loss: 1455.6808,
# Epoch 879 - Reconstruction Loss: 997.0193,
# Epoch 880 - Reconstruction Loss: 1329.7581,
# Epoch 881 - Reconstruction Loss: 935.5300,
# Epoch 882 - Reconstruction Loss: 1619.3943,
# Epoch 883 - Reconstruction Loss: 1492.0381,
# Epoch 884 - Reconstruction Loss: 799.1886,
# Epoch 885 - Reconstruction Loss: 1696.0571,
# Epoch 886 - Reconstruction Loss: 1067.5818,
# Epoch 887 - Reconstruction Loss: 1113.0554,
# Epoch 888 - Reconstruction Loss: 1290.5090,
# Epoch 889 - Reconstruction Loss: 763.8846,
# Epoch 890 - Reconstruction Loss: 1269.8297,
# Epoch 891 - Reconstruction Loss: 1178.5310,
# Epoch 892 - Reconstruction Loss: 1644.6932,
# Epoch 893 - Reconstruction Loss: 2019.6582,
# Epoch 894 - Reconstruction Loss: 1133.3975,
# Epoch 895 - Reconstruction Loss: 2197.0417,
# Epoch 896 - Reconstruction Loss: 1319.1178,
# Epoch 897 - Reconstruction Loss: 1084.9183,
# Epoch 898 - Reconstruction Loss: 1356.3992,
# Epoch 899 - Reconstruction Loss: 806.7820,
# Epoch 900 - Reconstruction Loss: 1750.1060,
# Epoch 901 - Reconstruction Loss: 1543.6132,
# Epoch 902 - Reconstruction Loss: 1002.0565,
# Epoch 903 - Reconstruction Loss: 945.0862,
# Epoch 904 - Reconstruction Loss: 1126.6887,
# Epoch 905 - Reconstruction Loss: 1342.1906,
# Epoch 906 - Reconstruction Loss: 1619.2128,
# Epoch 907 - Reconstruction Loss: 810.7231,
# Epoch 908 - Reconstruction Loss: 1059.6854,
# Epoch 909 - Reconstruction Loss: 1686.3923,
# Epoch 910 - Reconstruction Loss: 1163.9275,
# Epoch 911 - Reconstruction Loss: 1728.0504,
# Epoch 912 - Reconstruction Loss: 1381.2571,
# Epoch 913 - Reconstruction Loss: 792.7093,
# Epoch 914 - Reconstruction Loss: 1133.7029,
# Epoch 915 - Reconstruction Loss: 1591.1075,
# Epoch 916 - Reconstruction Loss: 750.2772,
# Epoch 917 - Reconstruction Loss: 1593.2302,
# Epoch 918 - Reconstruction Loss: 983.2042,
# Epoch 919 - Reconstruction Loss: 1318.1276,
# Epoch 920 - Reconstruction Loss: 976.0770,
# Epoch 921 - Reconstruction Loss: 1069.8422,
# Epoch 922 - Reconstruction Loss: 1161.2446,
# Epoch 923 - Reconstruction Loss: 1649.3225,
# Epoch 924 - Reconstruction Loss: 1420.9984,
# Epoch 925 - Reconstruction Loss: 892.6865,
# Epoch 926 - Reconstruction Loss: 1759.1346,
# Epoch 927 - Reconstruction Loss: 1460.1003,
# Epoch 928 - Reconstruction Loss: 1255.0432,
# Epoch 929 - Reconstruction Loss: 1403.5618,
# Epoch 930 - Reconstruction Loss: 1532.3250,
# Epoch 931 - Reconstruction Loss: 1607.6473,
# Epoch 932 - Reconstruction Loss: 1941.8022,
# Epoch 933 - Reconstruction Loss: 1258.3158,
# Epoch 934 - Reconstruction Loss: 1762.5465,
# Epoch 935 - Reconstruction Loss: 1301.0436,
# Epoch 936 - Reconstruction Loss: 1354.0002,
# Epoch 937 - Reconstruction Loss: 951.3465,
# Epoch 938 - Reconstruction Loss: 1896.2568,
# Epoch 939 - Reconstruction Loss: 1186.4976,
# Epoch 940 - Reconstruction Loss: 877.9356,
# Epoch 941 - Reconstruction Loss: 1822.7531,
# Epoch 942 - Reconstruction Loss: 1516.2256,
# Epoch 943 - Reconstruction Loss: 1091.8136,
# Epoch 944 - Reconstruction Loss: 1188.0713,
# Epoch 945 - Reconstruction Loss: 1558.1030,
# Epoch 946 - Reconstruction Loss: 2126.3853,
# Epoch 947 - Reconstruction Loss: 1169.9977,
# Epoch 948 - Reconstruction Loss: 1724.6986,
# Epoch 949 - Reconstruction Loss: 647.5404,
# Epoch 950 - Reconstruction Loss: 1950.0380,
# Epoch 951 - Reconstruction Loss: 1391.1075,
# Epoch 952 - Reconstruction Loss: 2300.1921,
# Epoch 953 - Reconstruction Loss: 1288.8561,
# Epoch 954 - Reconstruction Loss: 1526.5979,
# Epoch 955 - Reconstruction Loss: 1335.6145,
# Epoch 956 - Reconstruction Loss: 1277.9510,
# Epoch 957 - Reconstruction Loss: 1521.6711,
# Epoch 958 - Reconstruction Loss: 1336.3607,
# Epoch 959 - Reconstruction Loss: 972.0978,
# Epoch 960 - Reconstruction Loss: 1811.0948,
# Epoch 961 - Reconstruction Loss: 1396.5345,
# Epoch 962 - Reconstruction Loss: 1474.1959,
# Epoch 963 - Reconstruction Loss: 772.4697,
# Epoch 964 - Reconstruction Loss: 1508.2716,
# Epoch 965 - Reconstruction Loss: 1572.2979,
# Epoch 966 - Reconstruction Loss: 1331.5957,
# Epoch 967 - Reconstruction Loss: 2224.9636,
# Epoch 968 - Reconstruction Loss: 1268.9395,
# Epoch 969 - Reconstruction Loss: 1838.2876,
# Epoch 970 - Reconstruction Loss: 874.3292,
# Epoch 971 - Reconstruction Loss: 872.5294,
# Epoch 972 - Reconstruction Loss: 751.5843,
# Epoch 973 - Reconstruction Loss: 1916.3062,
# Epoch 974 - Reconstruction Loss: 1000.9543,
# Epoch 975 - Reconstruction Loss: 1894.2942,
# Epoch 976 - Reconstruction Loss: 1392.6573,
# Epoch 977 - Reconstruction Loss: 1786.1095,
# Epoch 978 - Reconstruction Loss: 1532.8109,
# Epoch 979 - Reconstruction Loss: 1038.0999,
# Epoch 980 - Reconstruction Loss: 1291.6761,
# Epoch 981 - Reconstruction Loss: 770.3911,
# Epoch 982 - Reconstruction Loss: 1844.1479,
# Epoch 983 - Reconstruction Loss: 1391.3640,
# Epoch 984 - Reconstruction Loss: 1510.3932,
# Epoch 985 - Reconstruction Loss: 1056.3798,
# Epoch 986 - Reconstruction Loss: 1001.7851,
# Epoch 987 - Reconstruction Loss: 2038.4457,
# Epoch 988 - Reconstruction Loss: 1937.1547,
# Epoch 989 - Reconstruction Loss: 1891.5745,
# Epoch 990 - Reconstruction Loss: 1304.0480,
# Epoch 991 - Reconstruction Loss: 1008.4099,
# Epoch 992 - Reconstruction Loss: 1216.3473,
# Epoch 993 - Reconstruction Loss: 1519.4452,
# Epoch 994 - Reconstruction Loss: 777.2137,
# Epoch 995 - Reconstruction Loss: 1383.0088,
# Epoch 996 - Reconstruction Loss: 1858.3445,
# Epoch 997 - Reconstruction Loss: 1397.5835,
# Epoch 998 - Reconstruction Loss: 664.2404,
# Epoch 999 - Reconstruction Loss: 1563.7949,
# Epoch 1000 - Reconstruction Loss: 1911.3544,
# Epoch 1001 - Reconstruction Loss: 1609.6337,
# Epoch 1002 - Reconstruction Loss: 1670.4868,
# Epoch 1003 - Reconstruction Loss: 987.4847,
# Epoch 1004 - Reconstruction Loss: 1334.5177,
# Epoch 1005 - Reconstruction Loss: 953.3293,
# Epoch 1006 - Reconstruction Loss: 1291.9036,
# Epoch 1007 - Reconstruction Loss: 2273.3352,
# Epoch 1008 - Reconstruction Loss: 1228.0685,
# Epoch 1009 - Reconstruction Loss: 1002.7529,
# Epoch 1010 - Reconstruction Loss: 1782.9022,
# Epoch 1011 - Reconstruction Loss: 1428.6166,
# Epoch 1012 - Reconstruction Loss: 1495.4937,
# Epoch 1013 - Reconstruction Loss: 1803.5693,
# Epoch 1014 - Reconstruction Loss: 1343.6304,
# Epoch 1015 - Reconstruction Loss: 1022.3344,
# Epoch 1016 - Reconstruction Loss: 1004.0266,
# Epoch 1017 - Reconstruction Loss: 1803.3741,
# Epoch 1018 - Reconstruction Loss: 1138.8517,
# Epoch 1019 - Reconstruction Loss: 1159.9226,
# Epoch 1020 - Reconstruction Loss: 1362.4998,
# Epoch 1021 - Reconstruction Loss: 1065.5785,
# Epoch 1022 - Reconstruction Loss: 1880.1434,
# Epoch 1023 - Reconstruction Loss: 1478.4246,
# Epoch 1024 - Reconstruction Loss: 833.3193,
# Epoch 1025 - Reconstruction Loss: 1279.3268,
# Epoch 1026 - Reconstruction Loss: 1041.6136,
# Epoch 1027 - Reconstruction Loss: 737.9233,
# Epoch 1028 - Reconstruction Loss: 1364.4619,
# Epoch 1029 - Reconstruction Loss: 889.5292,
# Epoch 1030 - Reconstruction Loss: 1347.3716,
# Epoch 1031 - Reconstruction Loss: 1924.0391,
# Epoch 1032 - Reconstruction Loss: 1843.2786,
# Epoch 1033 - Reconstruction Loss: 1007.7689,
# Epoch 1034 - Reconstruction Loss: 1613.9530,
# Epoch 1035 - Reconstruction Loss: 1442.7797,
# Epoch 1036 - Reconstruction Loss: 1114.3448,
# Epoch 1037 - Reconstruction Loss: 1189.3365,
# Epoch 1038 - Reconstruction Loss: 1305.1857,
# Epoch 1039 - Reconstruction Loss: 754.7411,
# Epoch 1040 - Reconstruction Loss: 1800.0188,
# Epoch 1041 - Reconstruction Loss: 847.1376,
# Epoch 1042 - Reconstruction Loss: 1613.3713,
# Epoch 1043 - Reconstruction Loss: 1208.8916,
# Epoch 1044 - Reconstruction Loss: 1436.9186,
# Epoch 1045 - Reconstruction Loss: 1965.3600,
# Epoch 1046 - Reconstruction Loss: 1576.4883,
# Epoch 1047 - Reconstruction Loss: 1574.7096,
# Epoch 1048 - Reconstruction Loss: 2033.9917,
# Epoch 1049 - Reconstruction Loss: 1430.0726,
# Epoch 1050 - Reconstruction Loss: 1669.6917,
# Epoch 1051 - Reconstruction Loss: 1435.3413,
# Epoch 1052 - Reconstruction Loss: 1611.8337,
# Epoch 1053 - Reconstruction Loss: 1404.6748,
# Epoch 1054 - Reconstruction Loss: 1020.6545,
# Epoch 1055 - Reconstruction Loss: 1644.4622,
# Epoch 1056 - Reconstruction Loss: 1513.3503,
# Epoch 1057 - Reconstruction Loss: 1626.3154,
# Epoch 1058 - Reconstruction Loss: 1877.0443,
# Epoch 1059 - Reconstruction Loss: 891.6312,
# Epoch 1060 - Reconstruction Loss: 1444.3997,
# Epoch 1061 - Reconstruction Loss: 1451.8767,
# Epoch 1062 - Reconstruction Loss: 920.4320,
# Epoch 1063 - Reconstruction Loss: 1538.4192,
# Epoch 1064 - Reconstruction Loss: 2051.3625,
# ...
# Epoch 1252 - Reconstruction Loss: 1813.9330,
# Epoch 1253 - Reconstruction Loss: 1151.0767,
# Epoch 1254 - Reconstruction Loss: 1718.1075,
# Epoch 1255 - Reconstruction Loss: 1144.8682,
# Epoch 1256 - Reconstruction Loss: 1304.5857,
# Epoch 1257 - Reconstruction Loss: 1572.6975,
# Epoch 1258 - Reconstruction Loss: 1841.4058,
# Epoch 1259 - Reconstruction Loss: 1386.6942,
# Epoch 1260 - Reconstruction Loss: 1609.9175,
# Epoch 1261 - Reconstruction Loss: 926.9526,
# Epoch 1262 - Reconstruction Loss: 1008.8781,
# Epoch 1263 - Reconstruction Loss: 1671.8170,
# Epoch 1264 - Reconstruction Loss: 1459.0938,
# Epoch 1265 - Reconstruction Loss: 956.0535,
# Epoch 1266 - Reconstruction Loss: 1071.6698,
# Epoch 1267 - Reconstruction Loss: 1677.3816,
# Epoch 1268 - Reconstruction Loss: 1012.3162,
# Epoch 1269 - Reconstruction Loss: 754.2620,
# Epoch 1270 - Reconstruction Loss: 751.5897,
# Epoch 1271 - Reconstruction Loss: 1198.0490,
# Epoch 1272 - Reconstruction Loss: 1181.1711,
# Epoch 1273 - Reconstruction Loss: 883.5319,
# Epoch 1274 - Reconstruction Loss: 1690.7065,
# Epoch 1275 - Reconstruction Loss: 1229.7034,
# Epoch 1276 - Reconstruction Loss: 1469.7242,
# Epoch 1277 - Reconstruction Loss: 1047.6632,
# Epoch 1278 - Reconstruction Loss: 1056.1586,
# Epoch 1279 - Reconstruction Loss: 1409.1218,
# Epoch 1280 - Reconstruction Loss: 1226.7186,
# Epoch 1281 - Reconstruction Loss: 2085.4583,
# Epoch 1282 - Reconstruction Loss: 2079.8735,
# Epoch 1283 - Reconstruction Loss: 1363.5691,
# Epoch 1284 - Reconstruction Loss: 1245.3563,
# Epoch 1285 - Reconstruction Loss: 1432.4255,
# Epoch 1286 - Reconstruction Loss: 1864.5891,
# Epoch 1287 - Reconstruction Loss: 1327.5535,
# Epoch 1288 - Reconstruction Loss: 1588.2111,
# Epoch 1289 - Reconstruction Loss: 1221.3906,
# Epoch 1290 - Reconstruction Loss: 1014.9502,
# Epoch 1291 - Reconstruction Loss: 1172.4044,
# Epoch 1292 - Reconstruction Loss: 1687.5680,
# Epoch 1293 - Reconstruction Loss: 1034.5822,
# Epoch 1294 - Reconstruction Loss: 1419.1199,
# Epoch 1295 - Reconstruction Loss: 1878.3180,
# Epoch 1296 - Reconstruction Loss: 1045.7366,
# Epoch 1297 - Reconstruction Loss: 1012.1028,
# Epoch 1298 - Reconstruction Loss: 1259.0386,
# Epoch 1299 - Reconstruction Loss: 875.2422,
# Epoch 1300 - Reconstruction Loss: 1135.6208,
# Epoch 1301 - Reconstruction Loss: 1408.1017,
# Epoch 1302 - Reconstruction Loss: 1024.6299,
# Epoch 1303 - Reconstruction Loss: 904.7479,
# Epoch 1304 - Reconstruction Loss: 1098.3066,
# Epoch 1305 - Reconstruction Loss: 879.5910,
# Epoch 1306 - Reconstruction Loss: 723.9720,
# Epoch 1307 - Reconstruction Loss: 1320.6830,
# Epoch 1308 - Reconstruction Loss: 1153.1942,
# Epoch 1309 - Reconstruction Loss: 1031.1466,
# Epoch 1310 - Reconstruction Loss: 1682.9941,
# Epoch 1311 - Reconstruction Loss: 1946.4742,
# Epoch 1312 - Reconstruction Loss: 1414.6735,
# Epoch 1313 - Reconstruction Loss: 800.1995,
# Epoch 1314 - Reconstruction Loss: 1564.5007,
# Epoch 1315 - Reconstruction Loss: 1095.3617,
# Epoch 1316 - Reconstruction Loss: 1905.9330,
# Epoch 1317 - Reconstruction Loss: 940.7979,
# Epoch 1318 - Reconstruction Loss: 1060.8727,
# Epoch 1319 - Reconstruction Loss: 1332.4163,
# Epoch 1320 - Reconstruction Loss: 1122.7283,
# Epoch 1321 - Reconstruction Loss: 949.4104,
# Epoch 1322 - Reconstruction Loss: 1182.3367,
# Epoch 1323 - Reconstruction Loss: 978.5405,
# Epoch 1324 - Reconstruction Loss: 984.7212,
# Epoch 1325 - Reconstruction Loss: 1560.0992,
# Epoch 1326 - Reconstruction Loss: 1975.1416,
# Epoch 1327 - Reconstruction Loss: 712.9199,
# Epoch 1328 - Reconstruction Loss: 1607.4716,
# Epoch 1329 - Reconstruction Loss: 1575.0095,
# Epoch 1330 - Reconstruction Loss: 1378.4930,
# Epoch 1331 - Reconstruction Loss: 1322.4310,
# Epoch 1332 - Reconstruction Loss: 1330.0643,
# Epoch 1333 - Reconstruction Loss: 1871.9761,
# Epoch 1334 - Reconstruction Loss: 1403.0024,
# Epoch 1335 - Reconstruction Loss: 1356.8903,
# Epoch 1336 - Reconstruction Loss: 999.8384,
# Epoch 1337 - Reconstruction Loss: 1144.3232,
# Epoch 1338 - Reconstruction Loss: 1121.8837,
# Epoch 1339 - Reconstruction Loss: 787.9321,
# Epoch 1340 - Reconstruction Loss: 1332.9139,
# Epoch 1341 - Reconstruction Loss: 1848.7208,
# Epoch 1342 - Reconstruction Loss: 1065.4728,
# Epoch 1343 - Reconstruction Loss: 2214.8691,
# Epoch 1344 - Reconstruction Loss: 899.7968,
# Epoch 1345 - Reconstruction Loss: 1648.2358,
# Epoch 1346 - Reconstruction Loss: 1124.8524,
# Epoch 1347 - Reconstruction Loss: 1327.6555,
# Epoch 1348 - Reconstruction Loss: 1056.1041,
# Epoch 1349 - Reconstruction Loss: 1234.4459,
# Epoch 1350 - Reconstruction Loss: 1508.8860,
# Epoch 1351 - Reconstruction Loss: 1317.9379,
# Epoch 1352 - Reconstruction Loss: 1522.9829,
# Epoch 1353 - Reconstruction Loss: 1558.5931,
# Epoch 1354 - Reconstruction Loss: 582.5399,
# Epoch 1355 - Reconstruction Loss: 1438.6860,
# Epoch 1356 - Reconstruction Loss: 1016.4382,
# Epoch 1357 - Reconstruction Loss: 1212.1158,
# Epoch 1358 - Reconstruction Loss: 1195.3629,
# Epoch 1359 - Reconstruction Loss: 1291.5072,
# Epoch 1360 - Reconstruction Loss: 995.1587,
# Epoch 1361 - Reconstruction Loss: 1180.0693,
# Epoch 1362 - Reconstruction Loss: 971.2949,
# Epoch 1363 - Reconstruction Loss: 1816.8997,
# Epoch 1364 - Reconstruction Loss: 968.3307,
# Epoch 1365 - Reconstruction Loss: 1261.6071,
# Epoch 1366 - Reconstruction Loss: 963.6625,
# Epoch 1367 - Reconstruction Loss: 1847.3201,
# Epoch 1368 - Reconstruction Loss: 896.9553,
# Epoch 1369 - Reconstruction Loss: 1260.5323,
# Epoch 1370 - Reconstruction Loss: 1543.2938,
# Epoch 1371 - Reconstruction Loss: 1846.5219,
# Epoch 1372 - Reconstruction Loss: 1244.5422,
# Epoch 1373 - Reconstruction Loss: 1809.6656,
# Epoch 1374 - Reconstruction Loss: 1238.3810,
# Epoch 1375 - Reconstruction Loss: 1219.0587,
# Epoch 1376 - Reconstruction Loss: 837.6267,
# Epoch 1377 - Reconstruction Loss: 1010.9145,
# Epoch 1378 - Reconstruction Loss: 1660.1019,
# Epoch 1379 - Reconstruction Loss: 1929.0361,
# Epoch 1380 - Reconstruction Loss: 1623.3158,
# Epoch 1381 - Reconstruction Loss: 1431.7554,
# Epoch 1382 - Reconstruction Loss: 1373.8479,
# Epoch 1383 - Reconstruction Loss: 1402.8043,
# Epoch 1384 - Reconstruction Loss: 1284.7123,
# Epoch 1385 - Reconstruction Loss: 877.0667,
# Epoch 1386 - Reconstruction Loss: 1198.6488,
# Epoch 1387 - Reconstruction Loss: 2020.5427,
# Epoch 1388 - Reconstruction Loss: 1735.3350,
# Epoch 1389 - Reconstruction Loss: 1794.6117,
# Epoch 1390 - Reconstruction Loss: 1763.0686,
# Epoch 1391 - Reconstruction Loss: 1195.7096,
# Epoch 1392 - Reconstruction Loss: 1545.2012,
# Epoch 1393 - Reconstruction Loss: 1766.0653,
# Epoch 1394 - Reconstruction Loss: 1417.2332,
# Epoch 1395 - Reconstruction Loss: 1315.5876,
# Epoch 1396 - Reconstruction Loss: 1259.9915,
# Epoch 1397 - Reconstruction Loss: 1363.2123,
# Epoch 1398 - Reconstruction Loss: 1058.4709,
# Epoch 1399 - Reconstruction Loss: 1005.7100,
# Epoch 1400 - Reconstruction Loss: 1599.8545,
# Epoch 1401 - Reconstruction Loss: 634.4357,
# Epoch 1402 - Reconstruction Loss: 1483.0361,
# Epoch 1403 - Reconstruction Loss: 1433.9712,
# Epoch 1404 - Reconstruction Loss: 2681.2666,
# Epoch 1405 - Reconstruction Loss: 1075.6608,
# Epoch 1406 - Reconstruction Loss: 1454.9960,
# Epoch 1407 - Reconstruction Loss: 1758.6274,
# Epoch 1408 - Reconstruction Loss: 1115.0253,
# Epoch 1409 - Reconstruction Loss: 1565.8353,
# Epoch 1410 - Reconstruction Loss: 996.2250,
# Epoch 1411 - Reconstruction Loss: 2124.2383,
# Epoch 1412 - Reconstruction Loss: 1113.3063,
# Epoch 1413 - Reconstruction Loss: 1487.2321,
# Epoch 1414 - Reconstruction Loss: 1415.2513,
# Epoch 1415 - Reconstruction Loss: 1215.8201,
# Epoch 1416 - Reconstruction Loss: 1254.8835,
# Epoch 1417 - Reconstruction Loss: 693.3873,
# Epoch 1418 - Reconstruction Loss: 1942.0535,
# Epoch 1419 - Reconstruction Loss: 1145.7843,
# Epoch 1420 - Reconstruction Loss: 1245.8625,
# Epoch 1421 - Reconstruction Loss: 1043.4089,
# Epoch 1422 - Reconstruction Loss: 1042.8793,
# Epoch 1423 - Reconstruction Loss: 1802.6428,
# Epoch 1424 - Reconstruction Loss: 1173.2852,
# Epoch 1425 - Reconstruction Loss: 1386.1273,
# Epoch 1426 - Reconstruction Loss: 1909.7922,
# Epoch 1427 - Reconstruction Loss: 1039.9316,
# Epoch 1428 - Reconstruction Loss: 1050.0403,
# Epoch 1429 - Reconstruction Loss: 1619.2944,
# Epoch 1430 - Reconstruction Loss: 1729.0792,
# Epoch 1431 - Reconstruction Loss: 1063.1104,
# Epoch 1432 - Reconstruction Loss: 1066.7659,
# Epoch 1433 - Reconstruction Loss: 1580.5393,
# Epoch 1434 - Reconstruction Loss: 1291.8602,
# Epoch 1435 - Reconstruction Loss: 1692.2960,
# Epoch 1436 - Reconstruction Loss: 1738.1952,
# Epoch 1437 - Reconstruction Loss: 1122.9635,
# Epoch 1438 - Reconstruction Loss: 1578.5085,
# Epoch 1439 - Reconstruction Loss: 1237.6006,
# Epoch 1440 - Reconstruction Loss: 1485.6683,
# Epoch 1441 - Reconstruction Loss: 1901.8033,
# Epoch 1442 - Reconstruction Loss: 2188.8435,
# Epoch 1443 - Reconstruction Loss: 1780.5691,
# Epoch 1444 - Reconstruction Loss: 1238.8239,
# Epoch 1445 - Reconstruction Loss: 1375.7500,
# Epoch 1446 - Reconstruction Loss: 1197.7213,
# Epoch 1447 - Reconstruction Loss: 1231.5598,
# Epoch 1448 - Reconstruction Loss: 1161.5420,
# Epoch 1449 - Reconstruction Loss: 1438.1694,
# Epoch 1450 - Reconstruction Loss: 1066.4205,
# Epoch 1451 - Reconstruction Loss: 1435.8413,
# Epoch 1452 - Reconstruction Loss: 1145.2417,
# Epoch 1453 - Reconstruction Loss: 1430.2451,
# Epoch 1454 - Reconstruction Loss: 1569.3893,
# Epoch 1455 - Reconstruction Loss: 1478.9456,
# Epoch 1456 - Reconstruction Loss: 1837.3103,
# Epoch 1457 - Reconstruction Loss: 1106.7285,
# Epoch 1458 - Reconstruction Loss: 987.1733,
# Epoch 1459 - Reconstruction Loss: 1419.2961,
# Epoch 1460 - Reconstruction Loss: 1323.9493,
# Epoch 1461 - Reconstruction Loss: 1665.1569,
# Epoch 1462 - Reconstruction Loss: 1038.2562,
# Epoch 1463 - Reconstruction Loss: 1521.2666,
# Epoch 1464 - Reconstruction Loss: 1009.9847,
# Epoch 1465 - Reconstruction Loss: 1510.5339,
# Epoch 1466 - Reconstruction Loss: 992.7349,
# Epoch 1467 - Reconstruction Loss: 1774.7191,
# Epoch 1468 - Reconstruction Loss: 1259.6530,
# Epoch 1469 - Reconstruction Loss: 1730.4141,
# Epoch 1470 - Reconstruction Loss: 1399.7130,
# Epoch 1471 - Reconstruction Loss: 1929.0621,
# Epoch 1472 - Reconstruction Loss: 1104.2198,
# Epoch 1473 - Reconstruction Loss: 1047.4202,
# Epoch 1474 - Reconstruction Loss: 1663.1102,
# Epoch 1475 - Reconstruction Loss: 1031.3951,
# Epoch 1476 - Reconstruction Loss: 1158.9587,
# Epoch 1477 - Reconstruction Loss: 1674.3544,
# Epoch 1478 - Reconstruction Loss: 1031.8628,
# Epoch 1479 - Reconstruction Loss: 1465.1393,
# Epoch 1480 - Reconstruction Loss: 1399.8691,
# Epoch 1481 - Reconstruction Loss: 1562.0330,
# Epoch 1482 - Reconstruction Loss: 1852.5225,
# Epoch 1483 - Reconstruction Loss: 1082.6738,
# Epoch 1484 - Reconstruction Loss: 1785.9510,
# Epoch 1485 - Reconstruction Loss: 1487.8708,
# Epoch 1486 - Reconstruction Loss: 1396.3254,
# Epoch 1487 - Reconstruction Loss: 1163.4023,
# Epoch 1488 - Reconstruction Loss: 1587.3705,
# Epoch 1489 - Reconstruction Loss: 1007.6415,
# Epoch 1490 - Reconstruction Loss: 1257.8525,
# Epoch 1491 - Reconstruction Loss: 1077.4421,
# Epoch 1492 - Reconstruction Loss: 1311.0088,
# Epoch 1493 - Reconstruction Loss: 1180.1714,
# Epoch 1494 - Reconstruction Loss: 1160.0648,
# Epoch 1495 - Reconstruction Loss: 1585.4379,
# Epoch 1496 - Reconstruction Loss: 2251.9358,
# Epoch 1497 - Reconstruction Loss: 972.2505,
# Epoch 1498 - Reconstruction Loss: 1494.9108,
# Epoch 1499 - Reconstruction Loss: 1881.6084,
# Epoch 1500 - Reconstruction Loss: 1212.2112,
# Epoch 1501 - Reconstruction Loss: 1765.1807,
# Epoch 1502 - Reconstruction Loss: 764.3735,
# Epoch 1503 - Reconstruction Loss: 1130.1880,
# Epoch 1504 - Reconstruction Loss: 1421.1088,
# Epoch 1505 - Reconstruction Loss: 1060.8202,
# Epoch 1506 - Reconstruction Loss: 1838.1351,
# Epoch 1507 - Reconstruction Loss: 879.1586,
# Epoch 1508 - Reconstruction Loss: 1425.2909,
# Epoch 1509 - Reconstruction Loss: 855.2762,
# Epoch 1510 - Reconstruction Loss: 1857.1884,
# Epoch 1511 - Reconstruction Loss: 1542.4395,
# Epoch 1512 - Reconstruction Loss: 950.8356,
# Epoch 1513 - Reconstruction Loss: 1448.2947,
# Epoch 1514 - Reconstruction Loss: 1303.6984,
# Epoch 1515 - Reconstruction Loss: 1469.6715,
# Epoch 1516 - Reconstruction Loss: 734.3625,
# Epoch 1517 - Reconstruction Loss: 1229.0267,
# Epoch 1518 - Reconstruction Loss: 1219.7531,
# Epoch 1519 - Reconstruction Loss: 1948.0833,
# Epoch 1520 - Reconstruction Loss: 1162.5115,
# Epoch 1521 - Reconstruction Loss: 1246.3541,
# Epoch 1522 - Reconstruction Loss: 1570.5723,
# Epoch 1523 - Reconstruction Loss: 920.0133,
# Epoch 1524 - Reconstruction Loss: 1776.2196,
# Epoch 1525 - Reconstruction Loss: 1055.6755,
# Epoch 1526 - Reconstruction Loss: 791.4840,
# Epoch 1527 - Reconstruction Loss: 1936.6672,
# Epoch 1528 - Reconstruction Loss: 1987.2881,
# Epoch 1529 - Reconstruction Loss: 1223.2139,
# Epoch 1530 - Reconstruction Loss: 1550.8285,
# Epoch 1531 - Reconstruction Loss: 1191.8513,
# Epoch 1532 - Reconstruction Loss: 1097.9099,
# Epoch 1533 - Reconstruction Loss: 1198.7996,
# Epoch 1534 - Reconstruction Loss: 1420.0299,
# Epoch 1535 - Reconstruction Loss: 1557.4928,
# Epoch 1536 - Reconstruction Loss: 1450.2006,
# Epoch 1537 - Reconstruction Loss: 897.6943,
# Epoch 1538 - Reconstruction Loss: 1066.5165,
# Epoch 1539 - Reconstruction Loss: 1638.6024,
# Epoch 1540 - Reconstruction Loss: 1484.3475,
# Epoch 1541 - Reconstruction Loss: 1809.2834,
# Epoch 1542 - Reconstruction Loss: 1439.3746,
# Epoch 1543 - Reconstruction Loss: 1238.6075,
# Epoch 1544 - Reconstruction Loss: 787.7278,
# Epoch 1545 - Reconstruction Loss: 1468.3386,
# Epoch 1546 - Reconstruction Loss: 740.1853,
# Epoch 1547 - Reconstruction Loss: 1074.7947,
# Epoch 1548 - Reconstruction Loss: 1039.9355,
# Epoch 1549 - Reconstruction Loss: 2021.4781,
# Epoch 1550 - Reconstruction Loss: 1268.6799,
# Epoch 1551 - Reconstruction Loss: 1928.4563,
# Epoch 1552 - Reconstruction Loss: 1104.1508,
# Epoch 1553 - Reconstruction Loss: 1930.4318,
# Epoch 1554 - Reconstruction Loss: 1393.3118,
# Epoch 1555 - Reconstruction Loss: 1275.9807,
# Epoch 1556 - Reconstruction Loss: 1121.3027,
# Epoch 1557 - Reconstruction Loss: 1623.2264,
# Epoch 1558 - Reconstruction Loss: 1477.3881,
# Epoch 1559 - Reconstruction Loss: 1943.9125,
# Epoch 1560 - Reconstruction Loss: 1085.2122,
# Epoch 1561 - Reconstruction Loss: 1253.1112,
# Epoch 1562 - Reconstruction Loss: 1834.9501,
# Epoch 1563 - Reconstruction Loss: 1695.8383,
# Epoch 1564 - Reconstruction Loss: 1587.5029,
# Epoch 1565 - Reconstruction Loss: 1030.3760,
# Epoch 1566 - Reconstruction Loss: 1783.9491,
# Epoch 1567 - Reconstruction Loss: 1046.9320,
# Epoch 1568 - Reconstruction Loss: 1200.4065,
# Epoch 1569 - Reconstruction Loss: 1679.1555,
# Epoch 1570 - Reconstruction Loss: 822.9888,
# Epoch 1571 - Reconstruction Loss: 962.2944,
# Epoch 1572 - Reconstruction Loss: 1718.9808,
# Epoch 1573 - Reconstruction Loss: 1331.2532,
# Epoch 1574 - Reconstruction Loss: 1321.4542,
# Epoch 1575 - Reconstruction Loss: 1441.1877,
# Epoch 1576 - Reconstruction Loss: 923.8113,
# Epoch 1577 - Reconstruction Loss: 1558.0797,
# Epoch 1578 - Reconstruction Loss: 908.5097,
# Epoch 1579 - Reconstruction Loss: 1242.5258,
# Epoch 1580 - Reconstruction Loss: 1001.8320,
# Epoch 1581 - Reconstruction Loss: 1515.7161,
# Epoch 1582 - Reconstruction Loss: 1276.1853,
# Epoch 1583 - Reconstruction Loss: 1180.8102,
# Epoch 1584 - Reconstruction Loss: 1267.5701,
# Epoch 1585 - Reconstruction Loss: 1688.7561,
# Epoch 1586 - Reconstruction Loss: 1063.0171,
# Epoch 1587 - Reconstruction Loss: 1750.9170,
# Epoch 1588 - Reconstruction Loss: 795.9655,
# Epoch 1589 - Reconstruction Loss: 1236.8505,
# Epoch 1590 - Reconstruction Loss: 1668.8503,
# Epoch 1591 - Reconstruction Loss: 1561.0868,
# Epoch 1592 - Reconstruction Loss: 1277.1941,
# Epoch 1593 - Reconstruction Loss: 1242.9468,
# Epoch 1594 - Reconstruction Loss: 1085.4028,
# Epoch 1595 - Reconstruction Loss: 2287.9548,
# Epoch 1596 - Reconstruction Loss: 1242.7002,
# Epoch 1597 - Reconstruction Loss: 2039.3313,
# Epoch 1598 - Reconstruction Loss: 1069.3278,
# Epoch 1599 - Reconstruction Loss: 1670.8192,

# %%
ae.load_model()
# Out:
# model loaded at gridformer\models

# %%
ae.evaluate(dataloader=dataloader, data_variance=data_variance)
# Out:
# Epoch 1599 - Reconstruction Loss: 1362.6445,

# %%
obs_t = torch.tensor(np.array(obs[0], np.float32), dtype=torch.float32, device=ae.device)

# %%
z, pred_x = ae.forward(obs_t.unsqueeze(0))

# %%
F.mse_loss(obs_t, pred_x)
# Out:
# C:\Users\Ernest\AppData\Local\Temp\ipykernel_6668\1498174816.py:1: UserWarning: Using a target size (torch.Size([1, 467])) that is different to the input size (torch.Size([467])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   F.mse_loss(obs_t, pred_x)
# tensor(134.5717, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
import torch

def discretize_continuous_values(z_continuous, num_categories):
    """
    Convert continuous values into discrete categorical values using fixed bins.

    Args:
        z_continuous (Tensor): Continuous latent variables of shape (batch_size, latent_dim).
        num_categories (int): Number of categories (bins) for each latent dimension.

    Returns:
        Tensor: Categorical latent variables of shape (batch_size, latent_dim), with discrete integer indices.
    """
    # Get the min and max range for the continuous values (assuming normalized range [-1, 1])
    z_min, z_max = -1.0, 1.0  # You can customize this range based on your encoder's output

    # Scale the continuous values to the range [0, num_categories)
    z_scaled = (z_continuous - z_min) / (z_max - z_min) * num_categories

    # Discretize by assigning to the nearest integer bucket
    z_discrete = torch.clamp(z_scaled.long(), 0, num_categories - 1)  # Ensure values are within valid category range

    return z_discrete

# %%
# Example Usage
latent_dim = 64  # Latent space size
num_categories = 64  # Number of categories per latent dimension

# Continuous encoder output
z_continuous = torch.randn(1, latent_dim)  # Example batch size 16

# Discretize
z_discrete = discretize_continuous_values(z_continuous, num_categories)

print("Discrete Latent Shape:", z_discrete.shape)  # (16, 64)
print("Discrete Latent Values:", z_discrete)
# Out:
# Discrete Latent Shape: torch.Size([1, 64])
# Discrete Latent Values: tensor([[35,  0, 63,  0, 63, 52,  0, 63, 63, 53, 51,  3, 11, 23,  3, 26, 63, 52,
#          32, 55, 60, 63, 63, 31, 10,  4, 23, 63, 21, 20, 63, 30, 27, 59, 63, 23,
#          20, 32, 63,  5, 56, 22, 27,  9,  0, 49, 28, 63,  0, 32,  0, 63, 51, 27,
#          21,  0, 46, 43, 32, 13, 61, 43, 47,  0]])
